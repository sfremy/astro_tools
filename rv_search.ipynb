# %%
import pandas as pd
import os

for file in os.listdir('harps_rv_bank'):
    if file.startswith('HARPS_RVBank_ver02.csv'):
        print('HARPS RV Bank match: ' + file)

# %%
names = [17051, 7788, 33564, 182572, 160032, 131156, 25998, 156897, 20794, 19373, 219623, 166620]

for name in names:
    print('Searching for: HD' + str(name))
    for file in os.listdir('harps_rv_bank'):
        if file.startswith('HD ' + str(name)):
            print('HARPS RV Bank match: ' + file)

    for file in os.listdir('keck_vels'):
        if file.startswith('HD ' + str(name)):
            print('Keck HIRES match: ' + file)

    for file in os.listdir('CLS_Rosenthal_2021'):
        if file.startswith('HD ' + str(name)):
            print('CLS match: ' + file)

    for file in os.listdir('Lick_Hamilton_F14'):
        if file.startswith('HD ' + str(name)):
            print('Lick/Hamilton match:' + file)

    for file in os.listdir('Laliotis_2023'):
        if file.startswith('HD ' + str(name)):
            print('Laliotis et al. 2023 match:' + file)

    print('-----------------------------------')
    
    #Note - Don't take Keck & HIRES data from CLS if you can help it
# Out:
# Searching for: HD17051
# HARPS RV Bank match: HD 17051.csv
# HARPS RV Bank match: HD 170514.csv
# Keck HIRES match: HD 170512_KECK.vels
# -----------------------------------
# Searching for: HD7788
# -----------------------------------
# Searching for: HD33564
# -----------------------------------
# Searching for: HD182572
# Keck HIRES match: HD 182572_KECK.vels
# CLS match: HD 182572_apf.csv
# CLS match: HD 182572_j.csv
# CLS match: HD 182572_k.csv
# -----------------------------------
# Searching for: HD160032
# -----------------------------------
# Searching for: HD131156
# CLS match: HD 131156_j.csv
# CLS match: HD 131156_lick.csv
# CLS match: HD 131156_apf.csv
# Lick/Hamilton match:HD 131156.csv
# Lick/Hamilton match:HD 131156B.csv
# -----------------------------------
# Searching for: HD25998
# Keck HIRES match: HD 25998_KECK.vels
# -----------------------------------
# Searching for: HD156897
# HARPS RV Bank match: HD 156897.csv
# -----------------------------------
# Searching for: HD20794
# HARPS RV Bank match: HD 20794.csv
# Laliotis et al. 2023 match:HD 20794_HARPS-Pre.csv
# Laliotis et al. 2023 match:HD 20794_UCLES.csv
# Laliotis et al. 2023 match:HD 20794_PFS-Pre.csv
# Laliotis et al. 2023 match:HD 20794_HARPS-Post.csv
# Laliotis et al. 2023 match:HD 20794_PFS-Post.csv
# -----------------------------------
# Searching for: HD19373
# Keck HIRES match: HD 19373_KECK.vels
# CLS match: HD 19373_apf.csv
# CLS match: HD 19373_k.csv
# CLS match: HD 19373_j.csv
# CLS match: HD 19373_lick.csv
# Lick/Hamilton match:HD 19373.csv
# -----------------------------------
# Searching for: HD219623
# Keck HIRES match: HD 219623_KECK.vels
# -----------------------------------
# Searching for: HD166620
# Keck HIRES match: HD 166620_KECK.vels
# CLS match: HD 166620_apf.csv
# CLS match: HD 166620_j.csv
# CLS match: HD 166620_k.csv
# CLS match: HD 166620_lick.csv
# Lick/Hamilton match:HD 166620.csv
# -----------------------------------

# %%
#Clean data formatting

# from astroquery.simbad import Simbad
# import time
# import os

# folder = 'Lick_Hamilton_F14'

# target = 'GL'

# for file in os.listdir(folder):
#     if file.startswith(target):
#         try:
#             obj_id = file.split('.')[0].replace('L','J')
#             j_k = file.split('.')[1].split('.')[0]
#             full_path = os.path.join(folder, file)

#             result_table = Simbad.query_objectids(obj_id)
#             id_list = result_table['ID'].tolist()
#             matching_id = next((obj_id for obj_id in id_list if 'HD' in obj_id), None)

#             if matching_id:
#                 print('Found HD catalog entry')
#                 new_name = matching_id + '_' + j_k
#                 os.rename(full_path, os.path.join(folder, new_name))
#             else:
#                 os.remove(full_path)

#             time.sleep(0.1)

#         except:
#             print('Error with file: ' + file)
#             continue


# #To-Do - g & s stars, HATS catalog stars

# %%
# folder = 'Lick_Hamilton_F14'

# for file in os.listdir(folder):
#     full_path = os.path.join(folder, file)
#     if file.endswith('_csv'):
#         new_name = file.replace('_csv','.csv')
#         os.rename(full_path, os.path.join(folder, new_name))

# %%
import ads
# Oops, I forgot to follow step 2 in "Getting Started"
ads.config.token = '...'
papers = ads.SearchQuery(q="object:HD17051")

for paper in papers:
    print(paper.title)
# Out:
# ---------------------------------------------------------------------------
# APIResponseError                          Traceback (most recent call last)
# Cell In[9], line 6
#       3 ads.config.token = 'l32Xfkr71MNtTYDgPc8nXSEgyV7VlnHxvqEFaqdh'
#       4 papers = ads.SearchQuery(q="object:HD17051")
# ----> 6 for paper in papers:
#       7     print(paper.title)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ads/search.py:512, in SearchQuery.__next__(self)
#     509 # Allow immediate iteration without forcing a user to call .execute()
#     510 # explicitly
#     511 if self.response is None:
# --> 512     self.execute()
#     514 try:
#     515     cur = self._articles[self.__iter_counter]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ads/search.py:543, in SearchQuery.execute(self)
#     537 def execute(self):
#     538     """
#     539     Sends the http request implied by the self.query
#     540     In addition, set up the request such that we can call next()
#     541     to provide the next page of results
#     542     """
# --> 543     self.response = SolrResponse.load_http_response(
#     544         self.session.get(self.HTTP_ENDPOINT, params=self.query)
#     545     )
#     547     # ADS will apply a ceiling to 'rows' and re-write the query
#     548     # This code checks if that happened by comparing the reponse
#     549     # "rows" with what we sent in our query
#     550     # references https://github.com/andycasey/ads/issues/45
#     551     recv_rows = int(self.response.responseHeader.get("params", {}).get("rows"))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ads/base.py:94, in APIResponse.load_http_response(cls, http_response)
#      89 """
#      90 This method should return an instantiated class and set its response
#      91 to the requests.Response object.
#      92 """
#      93 if not http_response.ok:
# ---> 94     raise APIResponseError(http_response.text)
#      95 c = cls(http_response)
#      96 c.response = http_response
#
# APIResponseError: '{\n  "responseHeader":{\n    "status":400,\n    "QTime":11,\n    "params":{\n      "q":"object:HD17051",\n      "fl":"id,author,first_author,bibcode,id,year,title",\n      "cursorMark":"*",\n      "start":"0",\n      "internal_logging_params":"X-Amzn-Trace-Id=Root=1-6800872d-173646096be77a6206cd5109",\n      "sort":"score desc,id desc",\n      "rows":"50",\n      "wt":"json"}},\n  "error":{\n    "metadata":[\n      "error-class","org.apache.solr.common.SolrException",\n      "root-error-class","org.apache.solr.common.SolrException"],\n    "msg":"org.apache.solr.search.SyntaxError: org.apache.solr.common.SolrException: undefined field object",\n    "code":400}}\n'

# %%
# !pip show ads
# Out:
# Name: ads
# Version: 0.12.7
# Summary: A Python module for NASA's ADS that doesn't suck.
# Home-page: http://www.github.com/andycasey/ads/
# Author: Andrew R. Casey
# Author-email: andy@astrowizici.st
# License: MIT
# Location: /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages
# Requires: mock, requests, six, werkzeug
# Required-by:
