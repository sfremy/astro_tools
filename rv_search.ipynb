# %%
import pandas as pd
import os

for file in os.listdir('harps_rv_bank'):
    if file.startswith('HARPS_RVBank_ver02.csv'):
        print('HARPS RV Bank match: ' + file)

# %%
names = [17051, 7788, 33564, 182572, 160032, 131156, 25998, 156897, 20794, 19373, 219623, 166620]

for name in names:
    print('Searching for: HD' + str(name))
    for file in os.listdir('harps_rv_bank'):
        if file.startswith('HD' + str(name)):
            print('HARPS RV Bank match: ' + file)

    for file in os.listdir('keck_vels'):
        if file.startswith('HD' + str(name)):
            print('Keck HIRES match: ' + file)

    for file in os.listdir('CLS_Rosenthal_2021 11-43-50-596'):
        if file.startswith(str(name)):
            print('CLS match: ' + file)

    for file in os.listdir('Lick_Hamilton_F14'):
        if file.startswith('HD' + str(name)):
            print('Lick/Hamilton match:' + file)

    for file in os.listdir('Laliotis_2023'):
        if file.startswith('HD' + str(name)):
            print('Laliotis et al. 2023 match:' + file)

    print('-----------------------------------')

    #Rosenthal - bd-/bd+, g, gl, hip, lhs, s
    #HARPS - BD-/BD+, CD-, EPIC, GJ, HATS-, HATS, HIP, K2-, TOI-, TOI, TYC, WASP
    #Keck - BD-/BD+, G, GL, HIP, HTR, RX, S, T-, TRES, V, VULCAN, WASP, XO
    #Lick - GL
# Out:
# Searching for: HD17051
# HARPS RV Bank match: HD170514.csv
# Keck HIRES match: HD170512_KECK.vels
# -----------------------------------
# Searching for: HD7788
# -----------------------------------
# Searching for: HD33564
# -----------------------------------
# Searching for: HD182572
# Keck HIRES match: HD182572_KECK.vels
# CLS match: 182572_k.csv
# CLS match: 182572_j.csv
# CLS match: 182572_apf.csv
# -----------------------------------
# Searching for: HD160032
# -----------------------------------
# Searching for: HD131156
# CLS match: 131156_j.csv
# CLS match: 131156_lick.csv
# CLS match: 131156_apf.csv
# -----------------------------------
# Searching for: HD25998
# Keck HIRES match: HD25998_KECK.vels
# -----------------------------------
# Searching for: HD156897
# -----------------------------------
# Searching for: HD20794
# HARPS RV Bank match: HD20794.csv
# Laliotis et al. 2023 match:HD20794_HARPS-Pre.csv
# Laliotis et al. 2023 match:HD20794_PFS-Pre.csv
# Laliotis et al. 2023 match:HD20794_PFS-Post.csv
# Laliotis et al. 2023 match:HD20794_UCLES.csv
# Laliotis et al. 2023 match:HD20794_HARPS-Post.csv
# -----------------------------------
# Searching for: HD19373
# Keck HIRES match: HD19373_KECK.vels
# CLS match: 19373_j.csv
# CLS match: 19373_k.csv
# CLS match: 19373_apf.csv
# CLS match: 19373_lick.csv
# -----------------------------------
# Searching for: HD219623
# Keck HIRES match: HD219623_KECK.vels
# -----------------------------------
# Searching for: HD166620
# Keck HIRES match: HD166620_KECK.vels
# CLS match: 166620_lick.csv
# CLS match: 166620_apf.csv
# CLS match: 166620_k.csv
# CLS match: 166620_j.csv
# -----------------------------------
